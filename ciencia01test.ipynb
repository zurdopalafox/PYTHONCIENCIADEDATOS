# %%
num1 = 5
num = 14
suma = num + num1
suma
# Out:
# 19

# %% [markdown]
# Importamos la Libreria de pandas

# %%
import pandas as pd

# %% [markdown]
# Creamos Datos para Dataframe

# %%
datos = {
    "Nombres": ["Ana", "Carlos", "Beatriz", "David"],
    "Edad": [25, 30, 22, 35],
    "Ciudad": ["Madrid", "Barcelona", "Valencia", "Sevilla"]
}

# %% [markdown]
# Creamos un Dataframe con los datos

# %%
df = pd.DataFrame(datos)
df
# Out:
#    Nombres  Edad     Ciudad
# 0      Ana    25     Madrid
# 1   Carlos    30  Barcelona
# 2  Beatriz    22   Valencia
# 3    David    35    Sevilla

# %% [markdown]
# Voy a filtrar datos por edad

# %%
df[df['Edad'] > 24]
